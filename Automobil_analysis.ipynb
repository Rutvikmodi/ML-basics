# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
ds = pd.read_csv("C:/Users/Admin/Desktop/automobil.csv")

# %%
ds.head(10)
# Out:
#    3    ?  alfa-romero  gas    std   two  convertible  rwd  front   88.6  \
# 0  3    ?  alfa-romero  gas    std   two  convertible  rwd  front   88.6
# 1  1    ?  alfa-romero  gas    std   two    hatchback  rwd  front   94.5
# 2  2  164         audi  gas    std  four        sedan  fwd  front   99.8
# 3  2  164         audi  gas    std  four        sedan  4wd  front   99.4
# 4  2    ?         audi  gas    std   two        sedan  fwd  front   99.8
# 5  1  158         audi  gas    std  four        sedan  fwd  front  105.8
# 6  1    ?         audi  gas    std  four        wagon  fwd  front  105.8
# 7  1  158         audi  gas  turbo  four        sedan  fwd  front  105.8
# 8  0    ?         audi  gas  turbo   two    hatchback  4wd  front   99.5
# 9  2  192          bmw  gas    std   two        sedan  rwd  front  101.2
#
#    ...    130  mpfi  3.47  2.68     9  111  5000  21  27  13495
# 0  ...    130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# ...

# %%
ds.columns=['symboling', 'normalized losses', 'make','fuel type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','wheel-base','length','width','height','curb-weight','engine-type','num-of-cylinders','engine-size','fuel-system','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg','price']

# %%
ds.to_csv('automobil.csv',index=False)

# %%
ds.head()
# Out:
#    symboling normalized losses         make fuel type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1    hatchback          rwd           front        94.5  ...            152
# 2        sedan          fwd           front        99.8  ...            109
# 3        sedan          4wd           front        99.4  ...            136
# 4        sedan          fwd           front        99.8  ...            136
#
# ...

# %%
df_data=ds.replace('?',np.NaN)

# %%
df_data.isnull().sum()
# Out:
# symboling             0
# normalized losses    40
# make                  0
# fuel type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df_data
# Out:
#      symboling normalized losses         make fuel type aspiration  \
# 0            3               NaN  alfa-romero       gas        std
# 1            1               NaN  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               NaN         audi       gas        std
# 5            1               158         audi       gas        std
# 6            1               NaN         audi       gas        std
# 7            1               158         audi       gas      turbo
# 8            0               NaN         audi       gas      turbo
# 9            2               192          bmw       gas        std
# 10           0               192          bmw       gas        std
# 11           0               188          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
df_temp = ds[ds['normalized losses']!='?']

# %%
df_temp
# Out:
#      symboling normalized losses        make fuel type aspiration  \
# 2            2               164        audi       gas        std
# 3            2               164        audi       gas        std
# 5            1               158        audi       gas        std
# 7            1               158        audi       gas      turbo
# 9            2               192         bmw       gas        std
# 10           0               192         bmw       gas        std
# 11           0               188         bmw       gas        std
# 12           0               188         bmw       gas        std
# 17           2               121   chevrolet       gas        std
# 18           1                98   chevrolet       gas        std
# 19           0                81   chevrolet       gas        std
# 20           1               118       dodge       gas        std
# 21           1               118       dodge       gas        std
# ...

# %%
new_mean = np.mean(df_temp['normalized losses'].astype(int))

# %%
new_mean
# Out:
# 122.0

# %%
ds['normalized losses'] = ds['normalized losses'].replace('?',new_mean)

# %%
ds
# Out:
#      symboling normalized losses         make fuel type aspiration  \
# 0            3               122  alfa-romero       gas        std
# 1            1               122  alfa-romero       gas        std
# 2            2               164         audi       gas        std
# 3            2               164         audi       gas        std
# 4            2               122         audi       gas        std
# 5            1               158         audi       gas        std
# 6            1               122         audi       gas        std
# 7            1               158         audi       gas      turbo
# 8            0               122         audi       gas      turbo
# 9            2               192          bmw       gas        std
# 10           0               192          bmw       gas        std
# 11           0               188          bmw       gas        std
# 12           0               188          bmw       gas        std
# ...

# %%
df_temp = ds[ds['price']!='?']
new_mean = np.mean(df_temp['price'].astype(int))
ds['price'] = ds['price'].replace('?',new_mean)

# %%
df_temp = ds[ds['horsepower']!='?']
new_mean = np.mean(df_temp['horsepower'].astype(int))
ds['horsepower'] = ds['horsepower'].replace('?',new_mean)

# %%
df_temp = ds[ds['peak-rpm']!='?']
new_mean = np.mean(df_temp['peak-rpm'].astype(int))
ds['peak-rpm'] = ds['peak-rpm'].replace('?',new_mean)

# %%
df_temp = ds[ds['bore']!='?']
new_mean = np.mean(df_temp['bore'].astype(float))
ds['bore'] = ds['bore'].replace('?',new_mean)

# %%
df_temp = ds[ds['stroke']!='?']
new_mean = np.mean(df_temp['stroke'].astype(float))
ds['stroke'] = ds['stroke'].replace('?',new_mean)

# %%
ds['num-of-doors'] = ds['num-of-doors'].replace('?','four')

# %%
ds.head()
# Out:
#    symboling normalized losses         make fuel type aspiration num-of-doors  \
# 0          3               122  alfa-romero       gas        std          two
# 1          1               122  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               122         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1    hatchback          rwd           front        94.5  ...            152
# 2        sedan          fwd           front        99.8  ...            109
# 3        sedan          4wd           front        99.4  ...            136
# 4        sedan          fwd           front        99.8  ...            136
#
# ...

# %%
ds.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.075000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.200000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   204.000000   204.000000         204.000000  204.000000   204.000000
# mean   2555.602941   126.892157          10.148137   25.240196    30.769608
# std     521.960820    41.744569           3.981000    6.551513     6.898337
# ...

# %%
x=ds['horsepower']

# %%
np.count_nonzero(50)
# Out:
# 1

# %%
x
# Out:
# 0      111
# 1      154
# 2      102
# 3      115
# 4      110
# 5      110
# 6      110
# 7      140
# 8      160
# 9      101
# 10     101
# 11     121
# 12     121
# 13     121
# 14     182
# 15     182
# 16     182
# 17      48
# 18      70
# 19      70
# 20      68
# 21      68
# 22     102
# 23      68
# 24      68
# 25      68
# 26     102
# 27      88
# 28     145
# 29      58
#       ...
# 174     92
# 175     92
# 176     92
# 177    161
# 178    161
# 179    156
# 180    156
# 181     52
# 182     85
# 183     52
# 184     85
# 185     85
# 186     68
# 187    100
# 188     90
# 189     90
# 190    110
# 191     68
# 192     88
# 193    114
# 194    114
# 195    114
# 196    114
# 197    162
# 198    162
# 199    114
# 200    160
# 201    134
# 202    106
# 203    114
# Name: horsepower, Length: 204, dtype: object

# %%
plt.figure(1)
ds['engine-type'].value_counts(normalize=True).plot(kind='bar',color='red')
plt.title("Number of Engine Type frequency diagram")
plt.ylabel('Number of Engine Type')
plt.xlabel('engine-type');

plt.figure(2)
ds['num-of-doors'].value_counts(normalize=True).plot(kind='bar',color='blue')
plt.title("Number of Door frequency diagram")
plt.ylabel('Number of Doors')
plt.xlabel('num-of-doors');

plt.figure(3)
ds['fuel type'].value_counts(normalize=True).plot(kind='bar',color='green')
plt.title("Number of Fuel Type frequency diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('fuel-type');

plt.figure(4)
ds['body-style'].value_counts(normalize=True).plot(kind='bar',color='orange')
plt.title("Number of Body Style frequency diagram")
plt.ylabel('Number of vehicles')
plt.xlabel('body-style');
plt.tight_layout()
plt.show()
