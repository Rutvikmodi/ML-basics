# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
file = pd.read_csv("C:/Users/Admin/Downloads/train.csv")

# %%
file.columns
# Out:
# Index(['x', 'y'], dtype='object')

# %%
file.values
# Out:
# array([[24.0, 21.54945196],
#        [50.0, 47.46446305],
#        [15.0, 17.21865634],
#        ...,
#        [82.0, 88.60376995],
#        [66.0, 63.64868529],
#        [97.0, 94.9752655]], dtype=object)

# %%
file.head()
# Out:
#       x        y
# 0  24.0  21.5495
# 1  50.0  47.4645
# 2  15.0  17.2187
# 3  38.0  36.5864
# 4  87.0   87.289

# %%
a=file[['x']]
b=file[['y']]
a = a.apply(pd.to_numeric, errors='coerce')
b = b.apply(pd.to_numeric, errors='coerce')
a.fillna(a.mean(), inplace=True)
b.fillna(b.mean(), inplace=True)

# %%
x_train,x_test,y_train,y_test = train_test_split(a,b,test_size=0.2,random_state=0)

# %%
reg = LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
a
# Out:
#          x
# 0     24.0
# 1     50.0
# 2     15.0
# 3     38.0
# 4     87.0
# 5     36.0
# 6     12.0
# 7     81.0
# 8     25.0
# 9      5.0
# 10    16.0
# 11    16.0
# 12    24.0
# 13    39.0
# 14    54.0
# 15    60.0
# 16    26.0
# 17    73.0
# 18    29.0
# 19    31.0
# 20    68.0
# 21    87.0
# 22    58.0
# 23    54.0
# 24    84.0
# 25    58.0
# 26    49.0
# 27    20.0
# 28    90.0
# 29    48.0
# ..     ...
# 670   84.0
# 671   64.0
# 672   12.0
# 673   61.0
# 674   75.0
# 675   15.0
# 676  100.0
# 677   43.0
# 678   13.0
# 679   48.0
# 680   45.0
# 681   52.0
# 682   34.0
# 683   30.0
# 684   65.0
# 685  100.0
# 686   67.0
# 687   99.0
# 688   45.0
# 689   87.0
# 690   73.0
# 691    9.0
# 692   81.0
# 693   72.0
# 694   81.0
# 695   58.0
# 696   93.0
# 697   82.0
# 698   66.0
# 699   97.0
#
# [700 rows x 1 columns]

# %%
b
# Out:
#               y
# 0     21.549452
# 1     47.464463
# 2     17.218656
# 3     36.586398
# 4     87.288984
# 5     32.463875
# 6     10.780897
# 7     80.763399
# 8     24.612151
# 9      6.963319
# 10    11.237573
# 11    13.532902
# 12    24.603239
# 13    39.400500
# 14    48.437538
# 15    61.699003
# 16    26.928324
# 17    70.405206
# 18    29.340924
# 19    25.308952
# 20    69.029343
# 21    84.994847
# 22    57.043103
# 23    50.592199
# 24    83.027722
# 25    57.057527
# 26    47.958833
# 27    24.342264
# 28    94.684883
# 29    48.039707
# ..          ...
# 670   82.889358
# 671   63.613650
# 672   11.296272
# 673   60.022749
# 674   72.603393
# 675   11.879646
# 676  100.701274
# 677   45.124208
# 678   14.811068
# 679   48.093680
# 680   42.291457
# 681   52.733898
# 682   36.723970
# 683   28.645352
# 684   62.166753
# 685   95.584595
# 686   66.043253
# 687   99.956622
# 688   46.149420
# 689   89.137550
# 690   69.717878
# 691   12.317366
# 692   78.202963
# 693   71.309954
# 694   81.455447
# 695   58.595006
# 696   94.625094
# 697   88.603770
# 698   63.648685
# 699   94.975266
#
# [700 rows x 1 columns]

# %%
y_pred=reg.predict(x_test)

# %%
print(y_pred)
# Out:
# [[50.45400585]
#  [49.25716797]
#  [50.7906165 ]
#  [49.96779046]
#  [49.66858099]
#  [48.7335514 ]
#  [51.31423307]
#  [48.58394666]
#  [49.59377862]
#  [49.36937152]
#  [48.20993483]
#  [50.60361058]
#  [50.75321532]
#  [48.13513246]
#  [48.58394666]
#  [49.96779046]
#  [49.81818572]
#  [50.30440111]
#  [49.93038928]
#  [49.93038928]
#  [48.7335514 ]
#  [48.17253365]
#  [51.2394307 ]
#  [49.03276087]
#  [48.06033009]
#  [48.92055732]
#  [49.70598217]
#  [47.83592299]
#  [48.06033009]
#  [49.51897626]
#  [47.94812654]
#  [50.07999401]
#  [48.35953956]
#  [49.1823656 ]
#  [49.81818572]
#  [47.91072536]
#  [49.44417389]
#  [50.26699993]
#  [51.35163425]
#  [49.55637744]
#  [49.59377862]
#  [48.39694075]
#  [48.65874903]
#  [48.02292891]
#  [50.37920348]
#  [48.62134785]
#  [48.35953956]
#  [47.94812654]
#  [48.47174311]
#  [48.58394666]
#  [51.12722715]
#  [49.81818572]
#  [48.5091443 ]
#  [50.37920348]
#  [49.44417389]
#  [48.84575495]
#  [51.31423307]
#  [48.62134785]
#  [48.58394666]
#  [49.48157507]
#  [49.03276087]
#  [49.74338336]
#  [48.02292891]
#  [51.0150236 ]
#  [50.82801768]
#  [49.14496442]
#  [48.77095258]
#  [50.90282005]
#  [48.62134785]
#  [47.94812654]
#  [50.15479638]
#  [48.24733601]
#  [48.09773128]
#  [50.7906165 ]
#  [50.67841295]
#  [49.59377862]
#  [50.30440111]
#  [49.25716797]
#  [50.97762242]
#  [48.20993483]
#  [49.4067727 ]
#  [49.07016205]
#  [50.94022123]
#  [50.86541887]
#  [50.00519164]
#  [50.5662094 ]
#  [47.91072536]
#  [49.07016205]
#  [48.80835377]
#  [50.41660466]
#  [49.55637744]
#  [50.3418023 ]
#  [47.98552773]
#  [50.90282005]
#  [47.91072536]
#  [49.55637744]
#  [48.35953956]
#  [50.86541887]
#  [49.1823656 ]
#  [48.7335514 ]
#  [50.45400585]
#  [51.38903544]
#  [47.91072536]
#  [48.35953956]
#  [47.83592299]
#  [51.31423307]
#  [50.82801768]
#  [50.75321532]
#  [50.45400585]
#  [50.15479638]
#  [50.52880821]
#  [48.43434193]
#  [47.98552773]
#  [48.62134785]
#  [51.16462834]
#  [50.97762242]
#  [49.66858099]
#  [48.69615022]
#  [50.97762242]
#  [49.21976679]
#  [50.97762242]
#  [50.71581413]
#  [50.37920348]
#  [48.7335514 ]
#  [50.00519164]
#  [48.92055732]
#  [47.98552773]
#  [48.88315613]
#  [50.45400585]
#  [49.51897626]
#  [48.17253365]
#  [50.37920348]
#  [49.4067727 ]
#  [50.41660466]
#  [50.19219756]
#  [49.85558691]
#  [50.26699993]
#  [51.27683189]
#  [51.31423307]
#  [51.20202952]]

# %%
q=pd.DataFrame({'Predicted':[y_pred],'Actual':[y_test]})

# %%
q
# Out:
#                                               Actual  \
# 0               y
# 306  79.206101
# 604  41.022518
# 4...
#
#                                            Predicted
# 0  [[50.454005846457996], [49.25716797031269], [5...

# %%
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 24.468708976406788
# Mean Squared Error: 789.5226188098028
# Root Mean Squared Error: 28.098445131533573

# %%
plt.scatter(x_test, y_test,  color='black') 
plt.title('Test Data') 
plt.xlabel('X') 
plt.ylabel('Y') 
plt.xticks(()) 
plt.yticks(()) 
plt.plot(x_test,y_pred,color='red',linewidth=1)
plt.show()
